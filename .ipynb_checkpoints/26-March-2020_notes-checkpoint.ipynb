# %%
#Lince Rumainum
#26 March 2020
#Lecture 18

#Warm-Up

import numpy as np
import pylab

x = np.arrange(1,2*np.pi,0.01)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-363b3f5b892c> in <module>()
#       8 import pylab
#       9
# ---> 10 x = np.arrange(1,2*np.pi,0.01)
#
# AttributeError: module 'numpy' has no attribute 'arrange'

# %%
x
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-401b30e3b8b5> in <module>()
# ----> 1 x
#
# NameError: name 'x' is not defined

# %%
pylab.subplot(2,2,1)
pylab.plot(t,np.sin(t), color = 'green')

# %%
import matplotlib.pyplot as plt
Y=[1,4,7,2,4,9,1,5,7,9,3,3,2,4,6,5,5,5,7,9,9,1,3,7,8]
u = plt.hist (Y, bins= 5,)
plt.xlabel("Category")
plt.ylabel("Frequency")
plt.show()

# %%
import matplotlib.pyplot as plt
Y=[1,4,7,2,4,9,1,5,7,9,3,3,2,4,6,5,5,5,7,9,9,1,3,7,8]
#DELETE BINS 5
u = plt.hist (Y)
plt.xlabel("Category")
plt.ylabel("Frequency")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
txtLabels = 'Cats', 'Dogs', 'Frogs', 'Others'
fractions = [45, 30, 15, 10]
offsets =(0, 0.05, 0, 0)
plt.pie(fractions, explode=offsets, labels = txtLabels,
        autopct='%1.1f%%', startangle = 90,
        colors= sns.color_palette ('muted'))
plt.axis('equal')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
txtLabels = 'Cats', 'Dogs', 'Frogs', 'Others'
fractions = [45, 30, 15, 10]
#CHANGE THE SECOND OFFSET TO 0
offsets =(0, 0, 0, 0)
#CHANGE COLOR TO BRIGHT
plt.pie(fractions, explode=offsets, labels = txtLabels,
        autopct='%1.1f%%', startangle = 90,
        colors= sns.color_palette ('bright'))
plt.axis('equal')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
txtLabels = 'Cats', 'Dogs', 'Frogs', 'Others'
fractions = [45, 30, 15, 10]
#CHANGE THE SECOND OFFSET TO 0
offsets =(0, 0, 0, 0)
# COLOR CAN BE: There are six variations of the default theme: 
# deep, muted, pastel, bright, dark, and colorblind
# autopct 1.2 have 2 digits after decimal
plt.pie(fractions, explode=offsets, labels = txtLabels,
        autopct='%1.2f%%', startangle = 90,
        colors= sns.color_palette ('pastel'))
plt.axis('equal')
plt.show()

# %%
import numpy as np 
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

x = np.linspace(1,7,50)
y = 3 + 2*x + 1.5*np.random.randn(len(x))
df = pd.DataFrame({'xData':x, 'yData':y})
sns.regplot('xData', 'yData', data =df)
plt.show()

# %%
import numpy as np
import pandas as pd

t = np.arange(0, 10, 0.1)
x = np.sin(t)
y = np.cos(t)
df = pd.DataFrame({'Time': t, 'x':x, 'y':y})

# %%
df
# Out:
#     Time         x         y
# 0    0.0  0.000000  1.000000
# 1    0.1  0.099833  0.995004
# 2    0.2  0.198669  0.980067
# 3    0.3  0.295520  0.955336
# 4    0.4  0.389418  0.921061
# 5    0.5  0.479426  0.877583
# 6    0.6  0.564642  0.825336
# 7    0.7  0.644218  0.764842
# 8    0.8  0.717356  0.696707
# 9    0.9  0.783327  0.621610
# 10   1.0  0.841471  0.540302
# 11   1.1  0.891207  0.453596
# 12   1.2  0.932039  0.362358
# 13   1.3  0.963558  0.267499
# 14   1.4  0.985450  0.169967
# 15   1.5  0.997495  0.070737
# 16   1.6  0.999574 -0.029200
# 17   1.7  0.991665 -0.128844
# 18   1.8  0.973848 -0.227202
# 19   1.9  0.946300 -0.323290
# 20   2.0  0.909297 -0.416147
# 21   2.1  0.863209 -0.504846
# 22   2.2  0.808496 -0.588501
# 23   2.3  0.745705 -0.666276
# 24   2.4  0.675463 -0.737394
# 25   2.5  0.598472 -0.801144
# 26   2.6  0.515501 -0.856889
# 27   2.7  0.427380 -0.904072
# 28   2.8  0.334988 -0.942222
# 29   2.9  0.239249 -0.970958
# ..   ...       ...       ...
# ...

# %%
df["Time"] # OR we can use df.Time
# Out:
# 0     0.0
# 1     0.1
# 2     0.2
# 3     0.3
# 4     0.4
# 5     0.5
# 6     0.6
# 7     0.7
# 8     0.8
# 9     0.9
# 10    1.0
# 11    1.1
# 12    1.2
# 13    1.3
# 14    1.4
# 15    1.5
# 16    1.6
# 17    1.7
# 18    1.8
# 19    1.9
# 20    2.0
# 21    2.1
# 22    2.2
# 23    2.3
# 24    2.4
# 25    2.5
# 26    2.6
# 27    2.7
# 28    2.8
# 29    2.9
#      ...
# 70    7.0
# 71    7.1
# 72    7.2
# 73    7.3
# 74    7.4
# 75    7.5
# 76    7.6
# 77    7.7
# 78    7.8
# 79    7.9
# 80    8.0
# 81    8.1
# 82    8.2
# 83    8.3
# 84    8.4
# 85    8.5
# 86    8.6
# 87    8.7
# 88    8.8
# 89    8.9
# 90    9.0
# 91    9.1
# 92    9.2
# 93    9.3
# 94    9.4
# 95    9.5
# 96    9.6
# 97    9.7
# 98    9.8
# 99    9.9
# Name: Time, Length: 100, dtype: float64

# %%
df.Time # OR we can use df["Time"]
# Out:
# 0     0.0
# 1     0.1
# 2     0.2
# 3     0.3
# 4     0.4
# 5     0.5
# 6     0.6
# 7     0.7
# 8     0.8
# 9     0.9
# 10    1.0
# 11    1.1
# 12    1.2
# 13    1.3
# 14    1.4
# 15    1.5
# 16    1.6
# 17    1.7
# 18    1.8
# 19    1.9
# 20    2.0
# 21    2.1
# 22    2.2
# 23    2.3
# 24    2.4
# 25    2.5
# 26    2.6
# 27    2.7
# 28    2.8
# 29    2.9
#      ...
# 70    7.0
# 71    7.1
# 72    7.2
# 73    7.3
# 74    7.4
# 75    7.5
# 76    7.6
# 77    7.7
# 78    7.8
# 79    7.9
# 80    8.0
# 81    8.1
# 82    8.2
# 83    8.3
# 84    8.4
# 85    8.5
# 86    8.6
# 87    8.7
# 88    8.8
# 89    8.9
# 90    9.0
# 91    9.1
# 92    9.2
# 93    9.3
# 94    9.4
# 95    9.5
# 96    9.6
# 97    9.7
# 98    9.8
# 99    9.9
# Name: Time, Length: 100, dtype: float64

# %%
df2 = df[['Time', 'x']]

# %%
df2
# Out:
#     Time         x
# 0    0.0  0.000000
# 1    0.1  0.099833
# 2    0.2  0.198669
# 3    0.3  0.295520
# 4    0.4  0.389418
# 5    0.5  0.479426
# 6    0.6  0.564642
# 7    0.7  0.644218
# 8    0.8  0.717356
# 9    0.9  0.783327
# 10   1.0  0.841471
# 11   1.1  0.891207
# 12   1.2  0.932039
# 13   1.3  0.963558
# 14   1.4  0.985450
# 15   1.5  0.997495
# 16   1.6  0.999574
# 17   1.7  0.991665
# 18   1.8  0.973848
# 19   1.9  0.946300
# 20   2.0  0.909297
# 21   2.1  0.863209
# 22   2.2  0.808496
# 23   2.3  0.745705
# 24   2.4  0.675463
# 25   2.5  0.598472
# 26   2.6  0.515501
# 27   2.7  0.427380
# 28   2.8  0.334988
# 29   2.9  0.239249
# ..   ...       ...
# 70   7.0  0.656987
# 71   7.1  0.728969
# 72   7.2  0.793668
# 73   7.3  0.850437
# 74   7.4  0.898708
# 75   7.5  0.938000
# 76   7.6  0.967920
# 77   7.7  0.988168
# 78   7.8  0.998543
# 79   7.9  0.998941
# 80   8.0  0.989358
# 81   8.1  0.969890
# 82   8.2  0.940731
# 83   8.3  0.902172
# 84   8.4  0.854599
# ...

# %%
df2[4:10] #from row 5 to 10
# Out:
#    Time         x
# 4   0.4  0.389418
# 5   0.5  0.479426
# 6   0.6  0.564642
# 7   0.7  0.644218
# 8   0.8  0.717356
# 9   0.9  0.783327

# %%
# Get column Time and x
# Get row 5 to 10
df[['Time', 'x']][4:10]
# Out:
#    Time         x
# 4   0.4  0.389418
# 5   0.5  0.479426
# 6   0.6  0.564642
# 7   0.7  0.644218
# 8   0.8  0.717356
# 9   0.9  0.783327

# %%
#Bar Plot
#number of observation is 10 with 4 variables
#grouping by columns
df = pd.DataFrame(np.random.rand(10,4), columns = ['a','b','c','d'])
df.plot(kind='bar', grid = False)
plt.show()

# %%
# Practice 1
import numpy as np
import matplotlib.pyplot as plt

# 500 random numbers and since it's between 0 and 1, mulitply by 100
Y = np.random.rand(500) * 100
u = plt.hist (Y, bins= 10,)
plt.xlabel("Category")
plt.ylabel("Frequency")
plt.show()

# %%
#Practice 2
#Bar Plot
#number of observation is 10 with 4 variables
#grouping by columns
df = pd.DataFrame(np.random.randint(20,150,size=(10,8)), 
    columns = ['p1','p2','p3','p4','p5','p6','p7','p8'])
df.plot(kind='bar', grid = False)
plt.show()

# %%
df
# Out:
#     p1   p2   p3   p4   p5   p6   p7   p8
# 0  122  116  128   62   36   83  113  118
# 1   58  128  109   48  108   69  147   78
# 2  116   52   56   43  138   56  112  115
# 3  127  132   55  107  148   85  120  110
# 4   51   53  133   96   61   36   78  119
# 5   58  147   49  118  127  139   74   62
# 6   46   23   69  146  105   86   70   26
# 7  117   95   50   67   53   49   31   72
# 8   74   79   61   60  103   37   65  127
# 9   81  115  113  142   35   64   22   62

# %%
df.plot(kind='bar', grid = True, legend = 'top-right')
plt.show()

# %%
#Practice 3
import seaborn as sns
import matplotlib.pyplot as plt
txtLabels = 'Cherry', 'Peach', 'Apple', 'Orange', 'Blueberry', 'Raspberry', 'Strawberry', 'Grape'
fractions = [5, 12, 20, 25, 8, 7, 13, 10]
offsets =(0.05, 0.05, 0.05, 0.05, 0.05, 0.05, 0.05, 0.05) #OPTIONAL
plt.pie(fractions, explode=offsets, labels = txtLabels,
        autopct='%1.2f%%', startangle = 90,
        colors= sns.color_palette ('deep'))
plt.axis('equal')
plt.show()
